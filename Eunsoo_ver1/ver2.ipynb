# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import os
import string
import missingno as msno

# %%
dat = pd.read_json('/content/drive/My Drive/Python/Project/dataengineer.json',lines=True)

# %%
len(dat)
# Out:
# 1008

# %%
msno.matrix(dat)

# %%
import re
import nltk
nltk.download('stopwords')
stopword = nltk.corpus.stopwords.words('english')
wn = nltk.WordNetLemmatizer()
nltk.download('wordnet')
def remove_punct(text):
    text_nopunct = "".join([char for char in text if char not in string.punctuation])
    return text_nopunct
def tokenize(text):
    tokens = re.split('\W+', text)
    return tokens
def remove_stopwords(tokenized_list):
    text = [word for word in tokenized_list if word not in stopword]
    return text
def lemmatizing(tokenized_text):
    text = [wn.lemmatize(word) for word in tokenized_text]
    return text
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
dat.head()
# Out:
#                                     _id  ... Languages
# 0  {'$oid': '5dca1376f68f858820733c99'}  ...       NaN
# 1  {'$oid': '5dca1380f68f858820733c9b'}  ...       NaN
# 2  {'$oid': '5dca13b2f68f858820733c9d'}  ...       NaN
# 3  {'$oid': '5dca13bff68f858820733c9f'}  ...       NaN
# 4  {'$oid': '5dca13caf68f858820733ca1'}  ...       NaN
#
# [5 rows x 14 columns]

# %% [markdown]
# ## SKILL

# %%
dat.columns
# Out:
# Index(['_id', 'ProfileID', 'Job Title', 'Location', 'Profile Summary',
#        'Experience', 'Education', 'Skills & Endorsements',
#        'Industry Knowledge', 'Tools & Technologies', 'Other Skills',
#        'Date Captured', 'Interpersonal Skills', 'Languages'],
#       dtype='object')

# %%
df_sk1 = dat['Skills & Endorsements']
df_sk2 = dat['Tools & Technologies']
df_sk3 = dat['Other Skills']
df_sk4 = dat['Interpersonal Skills']
df_sk5 = dat['Industry Knowledge']

# %%
## doing by all row
skill_list1 = []
for idx in range(len(df_sk1)):
    
    ## doing by all dict in one row
    skill_temp = []
    for i in range(len(df_sk1.iloc[idx])):
        ## doing by one dictionary
        for k,v in df_sk1.iloc[idx][i].items():
            #v.lower()
            skill_temp.append(v.lower())
    
    skill_list1.append(skill_temp)

# %%
all_skill1 = []
for idx in range(len(skill_list1)):
    for i,v in enumerate(skill_list1[idx]):
        all_skill1.append(v)

# %%
tr = 0
for i in range(len(all_skill1)):
    if all_skill1[i]=='python':
        tr+=1
tr
# Out:
# 270

# %%
pd.Series(all_skill1).value_counts().iloc[:50]
# Out:
# python                            270
# sql                               222
# java                              179
# data warehousing                  118
# machine learning                   92
# hadoop                             90
# data analysis                      87
# r                                  66
# business intelligence              58
# apache spark                       54
# etl                                52
# databases                          49
# big data                           48
# c++                                47
# c                                  40
# scala                              39
# microsoft office                   38
# pl/sql                             33
# software development               31
# data engineering                   31
# amazon web services (aws)          31
# javascript                         28
# oracle                             28
# tableau                            27
# data science                       27
# ...

# %%
def isNAN(num):
    return num!=num

# %%
for idx in range(len(df_sk2)):
    if isNAN(df_sk2.iloc[idx])==True:
        df_sk2.iloc[idx]=[]

# %%
## doing by all row 
skill_list2 = []
for idx in range(len(df_sk2)):
    
    ## doing by all dict in one row
    skill_temp = []
    for i in range(len(df_sk2.iloc[idx])):
        ## doing by one dictionary
        for k,v in df_sk2.iloc[idx][i].items():
            #v.lower()
            skill_temp.append(v.lower())
    
    skill_list2.append(skill_temp)

all_skill2 = []
for idx in range(len(skill_list2)):
    for i,v in enumerate(skill_list2[idx]):
        all_skill2.append(v)

# %%
## if value is nan then change empty list
for idx in range(len(df_sk3)):
    if isNAN(df_sk3.iloc[idx])==True:
        df_sk3.iloc[idx]=[]
## doing by all row 
skill_list3 = []
for idx in range(len(df_sk3)):
    
    ## doing by all dict in one row
    skill_temp = []
    for i in range(len(df_sk3.iloc[idx])):
        ## doing by one dictionary
        for k,v in df_sk3.iloc[idx][i].items():
            #v.lower()
            skill_temp.append(v.lower())
    
    skill_list3.append(skill_temp)

all_skill3 = []
for idx in range(len(skill_list3)):
    for i,v in enumerate(skill_list3[idx]):
        all_skill3.append(v)

# %%
## if value is nan then change empty list
for idx in range(len(df_sk4)):
    if isNAN(df_sk4.iloc[idx])==True:
        df_sk4.iloc[idx]=[]
## doing by all row 
skill_list4 = []
for idx in range(len(df_sk4)):
    
    ## doing by all dict in one row
    skill_temp = []
    for i in range(len(df_sk4.iloc[idx])):
        ## doing by one dictionary
        for k,v in df_sk4.iloc[idx][i].items():
            #v.lower()
            skill_temp.append(v.lower())
    
    skill_list4.append(skill_temp)

all_skill4 = []
for idx in range(len(skill_list4)):
    for i,v in enumerate(skill_list4[idx]):
        all_skill4.append(v)

# %%
## if value is nan then change empty list
for idx in range(len(df_sk5)):
    if isNAN(df_sk5.iloc[idx])==True:
        df_sk5.iloc[idx]=[]
## doing by all row 
skill_list5 = []
for idx in range(len(df_sk5)):
    
    ## doing by all dict in one row
    skill_temp = []
    for i in range(len(df_sk5.iloc[idx])):
        ## doing by one dictionary
        for k,v in df_sk5.iloc[idx][i].items():
            #v.lower()
            skill_temp.append(v.lower())
    
    skill_list5.append(skill_temp)

all_skill5 = []
for idx in range(len(skill_list5)):
    for i,v in enumerate(skill_list5[idx]):
        all_skill5.append(v)

# %%
df_skill = pd.DataFrame({'skill1':skill_list1,'skill2':skill_list2,'skill3':skill_list3,'skill4':skill_list4,'skill5':skill_list5})

# %%
skill_integral = list()
for i in range(len(skill_list1)):
    skill_integral_row = list()
    
    skill_integral_row.extend(skill_list1[i])
    skill_integral_row.extend(skill_list2[i])
    skill_integral_row.extend(skill_list3[i])
    skill_integral_row.extend(skill_list4[i])
    skill_integral_row.extend(skill_list5[i])

    skill_integral.append(skill_integral_row)

# %%
df_skill['integral'] = skill_integral

# %%
skill_integral_all = list()
for i,v in enumerate(skill_integral):
    skill_integral_all.extend(v)

# %%
uniq_skill = pd.Series(skill_integral_all).unique()

# %%
tr = pd.DataFrame({'uniq':uniq_skill})
tr.to_csv('uniq.csv')

# %%
pd.Series(skill_integral_all).value_counts().iloc[:50]
# Out:
# sql                               766
# python                            696
# java                              559
# data analysis                     484
# hadoop                            481
# mysql                             372
# databases                         369
# machine learning                  361
# r                                 348
# apache spark                      343
# javascript                        341
# tableau                           336
# c++                               330
# data warehousing                  328
# big data                          328
# amazon web services (aws)         311
# microsoft office                  302
# hive                              298
# microsoft excel                   297
# linux                             295
# business intelligence             287
# c                                 283
# html                              283
# software development              250
# microsoft sql server              247
# ...

# %%
tr.iloc[90:100]
# Out:
#                             uniq
# 90  microsoft visual studio code
# 91                        ����ͼ�
# 92                  c++ language
# 93                 ������ ������
# 94                   ������ ����
# 95                      �����ͺм�
# 96                  �����ϳ����ͼ�
# 97                          ����
# 98                  data science
# 99                        korean

# %% [markdown]
# ## Education

# %%
df_edu = dat['Education']

# %%
## extend for entire row
school_list = []
degree_list = []

for idx in range(len(df_edu)):
    school_row = []
    degree_row = []
    ## for dictionary in a row
    for k,v in df_edu.iloc[idx][0].items():
        if k=='School':
            school_row.append(v)
        elif k=='Degree':
            degree_row.append(v)


    school_list.append(school_row)
    degree_list.append(degree_row)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-97-c0763b2fee22> in <module>()
#       6     degree_row = []
#       7     ## for dictionary in a row
# ----> 8     for k,v in df_edu.iloc[idx][0].items():
#       9         if k=='School':
#      10             school_row.append(v)
#
# IndexError: list index out of range

# %%
tr = df_edu.iloc[75:78]

# %%
for idx in range(len(tr)):
    if tr.iloc[idx]==[]:
        pass
    else:
        for k,v in tr.iloc[idx][0].items():
            if k=='School':
                print(v)
            elif k=='Degree':
                print(v)
# Out:
# Cornell University
# B.S. Economics, Natural Resources, Environmental Economics
# University of California, Davis
# Master of Science (MS) Mechanical Engineering

# %%
df_edu['School'] = None
df_edu['Degree'] = None
# df['Date Attended'] = None

for i in range(len(df_edu)):
    if dat['Education'][i] == []:
        pass
    else:
        df_edu['School'][i] = dat['Education'][i][0]['School']
        df_edu['Degree'][i] = dat['Education'][i][0]['Degree']
#         df['Date Attended'][i] = df['Education'][i][0]['Date Attended']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-e06a1eac815d> in <module>()
#       7         pass
#       8     else:
# ----> 9         df_edu['School'][i] = dat['Education'][i][0]['School']
#      10         df_edu['Degree'][i] = dat['Education'][i][0]['Degree']
#      11 #         df['Date Attended'][i] = df['Education'][i][0]['Date Attended']
#
# TypeError: 'NoneType' object does not support item assignment

# %%
df_edu[250:300]
# Out:
# 250    [{'School': 'University of California, Berkele...
# 251    [{'School': 'The University of Texas at Dallas...
# 252    [{'School': 'Georgia Institute of Technology',...
# 253    [{'School': 'Syracuse University School of Inf...
# 254    [{'School': 'New Jersey Institute of Technolog...
# 255    [{'School': 'Northern Illinois University', 'D...
# 256    [{'School': 'The University of Texas at Dallas...
# 257    [{'School': 'University of Pennsylvania', 'Deg...
# 258    [{'School': 'Northeastern University', 'Degree...
# 259    [{'School': 'The University of Connecticut', '...
# 260    [{'School': 'The Johns Hopkins University', 'D...
# 261    [{'School': 'The University of Texas at Arling...
# 262    [{'School': 'California State University-East ...
# 263    [{'School': 'University of Utah - David Eccles...
# 264    [{'School': 'Caltech', 'Degree': 'Master Elect...
# 265    [{'School': 'University of Virginia', 'Degree'...
# ...
